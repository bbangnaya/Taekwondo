# %%
Action_Num = [1,4,5,6,7,8,10,14]
type(Action_Num[2])
# Out:
# int

# %%
x = 2
type(x)

# %%
for file in file_list:

    vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01/T38_A01_S01.mp4')
    for Set in range(1, 13):
        os.mkdir(my_path + file_name + str(Set))
    file_name = 'T38_A01_S01.mp4'
    print('T%d_A%d_S%d.jpg',%Trainer, %Action,%Set)

# %%
import os
file_list = os.listdir('C:/Users/user/Desktop/Taekwondo/train/A01')
file_list
# Out:
# ['T01_A01_S01.mp4',
#  'T01_A01_S02.mp4',
#  'T01_A01_S03.mp4',
#  'T01_A01_S04.mp4',
#  'T01_A01_S05.mp4',
#  'T01_A01_S06.mp4',
#  'T01_A01_S07.mp4',
#  'T01_A01_S08.mp4',
#  'T01_A01_S09.mp4',
#  'T01_A01_S10.mp4',
#  'T01_A01_S11.mp4',
#  'T01_A01_S12.mp4',
#  'T02_A01_S01.mp4',
#  'T02_A01_S02.mp4',
#  'T02_A01_S03.mp4',
#  'T02_A01_S04.mp4',
#  'T02_A01_S05.mp4',
#  'T02_A01_S06.mp4',
#  'T02_A01_S07.mp4',
#  'T02_A01_S08.mp4',
#  'T02_A01_S09.mp4',
#  'T02_A01_S10.mp4',
#  'T02_A01_S11.mp4',
#  'T02_A01_S12.mp4',
#  'T03_A01_S01.mp4',
#  'T03_A01_S02.mp4',
#  'T03_A01_S03.mp4',
#  'T03_A01_S04.mp4',
#  'T03_A01_S05.mp4',
#  'T03_A01_S06.mp4',
#  'T03_A01_S07.mp4',
#  'T03_A01_S08.mp4',
#  'T03_A01_S09.mp4',
#  'T03_A01_S10.mp4',
#  'T03_A01_S11.mp4',
#  'T03_A01_S12.mp4',
#  'T04_A01_S01.mp4',
#  'T04_A01_S02.mp4',
#  'T04_A01_S03.mp4',
#  'T04_A01_S04.mp4',
#  'T04_A01_S05.mp4',
#  'T04_A01_S06.mp4',
#  'T04_A01_S07.mp4',
#  'T04_A01_S08.mp4',
#  'T04_A01_S09.mp4',
#  'T04_A01_S10.mp4',
#  'T04_A01_S11.mp4',
#  'T04_A01_S12.mp4',
#  'T05_A01_S01.mp4',
#  'T05_A01_S02.mp4',
#  'T05_A01_S03.mp4',
#  'T05_A01_S04.mp4',
#  'T05_A01_S05.mp4',
#  'T05_A01_S06.mp4',
#  'T05_A01_S07.mp4',
#  'T05_A01_S08.mp4',
#  'T05_A01_S09.mp4',
#  'T05_A01_S10.mp4',
#  'T05_A01_S11.mp4',
#  'T05_A01_S12.mp4',
#  'T06_A01_S01.mp4',
#  'T06_A01_S02.mp4',
#  'T06_A01_S03.mp4',
#  'T06_A01_S04.mp4',
#  'T06_A01_S05.mp4',
#  'T06_A01_S06.mp4',
#  'T06_A01_S07.mp4',
#  'T06_A01_S08.mp4',
#  'T06_A01_S09.mp4',
#  'T06_A01_S10.mp4',
#  'T06_A01_S11.mp4',
#  'T06_A01_S12.mp4',
#  'T07_A01_S01.mp4',
#  'T07_A01_S02.mp4',
#  'T07_A01_S03.mp4',
#  'T07_A01_S04.mp4',
#  'T38_A01_S03.mp4',
#  'T38_A01_S04.mp4',
#  'T38_A01_S05.mp4',
#  'T38_A01_S06.mp4',
#  'T38_A01_S07.mp4',
#  'T38_A01_S08.mp4',
#  'T39_A01_S01.mp4',
#  'T39_A01_S02.mp4',
#  'T39_A01_S03.mp4',
#  'T39_A01_S04.mp4',
#  'T39_A01_S05.mp4',
#  'T39_A01_S06.mp4',
#  'T39_A01_S07.mp4',
#  'T39_A01_S08.mp4',
#  'T39_A01_S09.mp4',
#  'T39_A01_S10.mp4',
#  'T39_A01_S11.mp4',
#  'T39_A01_S12.mp4',
#  'T40_A01_S01.mp4',
#  'T40_A01_S02.mp4',
#  'T40_A01_S03.mp4',
#  'T40_A01_S04.mp4',
#  'T40_A01_S05.mp4',
#  'T40_A01_S06.mp4',
#  'T40_A01_S07.mp4',
#  'T40_A01_S08.mp4',
#  'T40_A01_S09.mp4',
#  'T40_A01_S10.mp4',
#  'T40_A01_S11.mp4',
#  'T40_A01_S12.mp4',
#  'T41_A01_S01.mp4',
#  'T41_A01_S02.mp4',
#  'T41_A01_S03.mp4',
#  'T41_A01_S04.mp4',
#  'T41_A01_S05.mp4',
#  'T41_A01_S06.mp4',
#  'T41_A01_S07.mp4',
#  'T41_A01_S08.mp4',
#  'T41_A01_S09.mp4',
#  'T41_A01_S10.mp4',
#  'T41_A01_S11.mp4',
#  'T41_A01_S12.mp4']

# %%
file_name = []
for file in file_list:
    if file.count(".") == 1: 
        name = file.split('.')[0]
        file_name.append(name)
    else:
        for k in range(len(file)-1,0,-1):
            if file[k]=='.':
                file_name.append(file[:k])
                break
                
file_name
# Out:
# ['T01_A01_S01',
#  'T01_A01_S02',
#  'T01_A01_S03',
#  'T01_A01_S04',
#  'T01_A01_S05',
#  'T01_A01_S06',
#  'T01_A01_S07',
#  'T01_A01_S08',
#  'T01_A01_S09',
#  'T01_A01_S10',
#  'T01_A01_S11',
#  'T01_A01_S12',
#  'T02_A01_S01',
#  'T02_A01_S02',
#  'T02_A01_S03',
#  'T02_A01_S04',
#  'T02_A01_S05',
#  'T02_A01_S06',
#  'T02_A01_S07',
#  'T02_A01_S08',
#  'T02_A01_S09',
#  'T02_A01_S10',
#  'T02_A01_S11',
#  'T02_A01_S12',
#  'T03_A01_S01',
#  'T03_A01_S02',
#  'T03_A01_S03',
#  'T03_A01_S04',
#  'T03_A01_S05',
#  'T03_A01_S06',
#  'T03_A01_S07',
#  'T03_A01_S08',
#  'T03_A01_S09',
#  'T03_A01_S10',
#  'T03_A01_S11',
#  'T03_A01_S12',
#  'T04_A01_S01',
#  'T04_A01_S02',
#  'T04_A01_S03',
#  'T04_A01_S04',
#  'T04_A01_S05',
#  'T04_A01_S06',
#  'T04_A01_S07',
#  'T04_A01_S08',
#  'T04_A01_S09',
#  'T04_A01_S10',
#  'T04_A01_S11',
#  'T04_A01_S12',
#  'T05_A01_S01',
#  'T05_A01_S02',
#  'T05_A01_S03',
#  'T05_A01_S04',
#  'T05_A01_S05',
#  'T05_A01_S06',
#  'T05_A01_S07',
#  'T05_A01_S08',
#  'T05_A01_S09',
#  'T05_A01_S10',
#  'T05_A01_S11',
#  'T05_A01_S12',
#  'T06_A01_S01',
#  'T06_A01_S02',
#  'T06_A01_S03',
#  'T06_A01_S04',
#  'T06_A01_S05',
#  'T06_A01_S06',
#  'T06_A01_S07',
#  'T06_A01_S08',
#  'T06_A01_S09',
#  'T06_A01_S10',
#  'T06_A01_S11',
#  'T06_A01_S12',
#  'T07_A01_S01',
#  'T07_A01_S02',
#  'T07_A01_S03',
#  'T07_A01_S04',
#  'T07_A01_S05',
#  'T07_A01_S06',
#  'T07_A01_S07',
#  'T07_A01_S08',
#  'T07_A01_S09',
#  'T07_A01_S10',
#  'T07_A01_S11',
#  'T07_A01_S12',
#  'T08_A01_S01',
#  'T08_A01_S02',
#  'T08_A01_S03',
#  'T08_A01_S04',
#  'T08_A01_S05',
#  'T08_A01_S06',
#  'T08_A01_S07',
#  'T08_A01_S08',
#  'T08_A01_S09',
#  'T08_A01_S10',
#  'T08_A01_S11',
#  'T08_A01_S12',
#  'T09_A01_S01',
#  'T09_A01_S02',
#  'T09_A01_S03',
#  'T09_A01_S04',
#  'T09_A01_S05',
#  'T09_A01_S06',
#  'T09_A01_S07',
#  'T09_A01_S08',
#  'T09_A01_S09',
#  'T09_A01_S10',
#  'T09_A01_S11',
#  'T09_A01_S12',
#  'T10_A01_S01',
#  'T10_A01_S02',
#  'T10_A01_S03',
#  'T10_A01_S04',
#  'T10_A01_S05',
#  'T10_A01_S06',
#  'T10_A01_S07',
#  'T10_A01_S08',
#  'T10_A01_S09',
#  'T10_A01_S10',
#  'T10_A01_S11',
#  'T10_A01_S12',
#  'T11_A01_S01',
#  'T11_A01_S02',
#  'T11_A01_S03',
#  'T11_A01_S04',
#  'T11_A01_S05',
#  'T11_A01_S06',
#  'T11_A01_S07',
#  'T11_A01_S08',
#  'T11_A01_S09',
#  'T11_A01_S10',
#  'T11_A01_S11',
#  'T11_A01_S12',
#  'T12_A01_S01',
#  'T12_A01_S02',
#  'T12_A01_S03',
#  'T12_A01_S04',
#  'T12_A01_S05',
#  'T12_A01_S06',
#  'T12_A01_S07',
#  'T12_A01_S08',
#  'T12_A01_S09',
#  'T12_A01_S10',
#  'T12_A01_S11',
#  'T12_A01_S12',
#  'T13_A01_S01',
#  'T13_A01_S02',
#  'T13_A01_S03',
#  'T13_A01_S04',
#  'T13_A01_S05',
#  'T13_A01_S06',
#  'T13_A01_S07',
#  'T13_A01_S08',
#  'T13_A01_S09',
#  'T13_A01_S10',
#  'T13_A01_S11',
#  'T13_A01_S12',
#  'T14_A01_S01',
#  'T14_A01_S02',
#  'T14_A01_S03',
#  'T14_A01_S04',
#  'T14_A01_S05',
#  'T14_A01_S06',
#  'T14_A01_S07',
#  'T14_A01_S08',
#  'T14_A01_S09',
#  'T14_A01_S10',
#  'T14_A01_S11',
#  'T14_A01_S12',
#  'T15_A01_S01',
#  'T15_A01_S02',
#  'T15_A01_S03',
#  'T15_A01_S04',
#  'T15_A01_S05',
#  'T15_A01_S06',
#  'T15_A01_S07',
#  'T15_A01_S08',
#  'T15_A01_S09',
#  'T15_A01_S10',
#  'T15_A01_S11',
#  'T15_A01_S12',
#  'T16_A01_S01',
#  'T16_A01_S02',
#  'T16_A01_S03',
#  'T16_A01_S04',
#  'T16_A01_S05',
#  'T16_A01_S06',
#  'T16_A01_S07',
#  'T16_A01_S08',
#  'T16_A01_S09',
#  'T16_A01_S10',
#  'T16_A01_S11',
#  'T16_A01_S12',
#  'T17_A01_S01',
#  'T17_A01_S02',
#  'T17_A01_S03',
#  'T17_A01_S04',
#  'T17_A01_S05',
#  'T17_A01_S06',
#  'T17_A01_S07',
#  'T17_A01_S08',
#  'T17_A01_S09',
#  'T17_A01_S10',
#  'T17_A01_S11',
#  'T17_A01_S12',
#  'T18_A01_S01',
#  'T18_A01_S02',
#  'T18_A01_S03',
#  'T18_A01_S04',
#  'T18_A01_S05',
#  'T18_A01_S06',
#  'T18_A01_S07',
#  'T18_A01_S08',
#  'T18_A01_S09',
#  'T18_A01_S10',
#  'T18_A01_S11',
#  'T18_A01_S12',
#  'T19_A01_S01',
#  'T19_A01_S02',
#  'T19_A01_S03',
#  'T19_A01_S04',
#  'T19_A01_S05',
#  'T19_A01_S06',
#  'T19_A01_S07',
#  'T19_A01_S08',
#  'T19_A01_S09',
#  'T19_A01_S10',
#  'T19_A01_S11',
#  'T19_A01_S12',
#  'T20_A01_S01',
#  'T20_A01_S02',
#  'T20_A01_S03',
#  'T20_A01_S04',
#  'T20_A01_S05',
#  'T20_A01_S06',
#  'T20_A01_S07',
#  'T20_A01_S08',
#  'T20_A01_S09',
#  'T20_A01_S10',
#  'T20_A01_S11',
#  'T20_A01_S12',
#  'T21_A01_S01',
#  'T21_A01_S02',
#  'T21_A01_S03',
#  'T21_A01_S04',
#  'T21_A01_S05',
#  'T21_A01_S06',
#  'T21_A01_S07',
#  'T21_A01_S08',
#  'T21_A01_S09',
#  'T21_A01_S10',
#  'T21_A01_S11',
#  'T21_A01_S12',
#  'T22_A01_S01',
#  'T22_A01_S02',
#  'T22_A01_S03',
#  'T22_A01_S04',
#  'T22_A01_S05',
#  'T22_A01_S06',
#  'T22_A01_S07',
#  'T22_A01_S08',
#  'T22_A01_S09',
#  'T22_A01_S10',
#  'T22_A01_S11',
#  'T22_A01_S12',
#  'T23_A01_S01',
#  'T23_A01_S02',
#  'T23_A01_S03',
#  'T23_A01_S04',
#  'T23_A01_S05',
#  'T23_A01_S06',
#  'T23_A01_S07',
#  'T23_A01_S08',
#  'T23_A01_S09',
#  'T23_A01_S10',
#  'T23_A01_S11',
#  'T23_A01_S12',
#  'T24_A01_S01',
#  'T24_A01_S02',
#  'T24_A01_S03',
#  'T24_A01_S04',
#  'T24_A01_S05',
#  'T24_A01_S06',
#  'T24_A01_S07',
#  'T24_A01_S08',
#  'T24_A01_S09',
#  'T24_A01_S10',
#  'T24_A01_S11',
#  'T24_A01_S12',
#  'T25_A01_S01',
#  'T25_A01_S02',
#  'T25_A01_S03',
#  'T25_A01_S04',
#  'T25_A01_S05',
#  'T25_A01_S06',
#  'T25_A01_S07',
#  'T25_A01_S08',
#  'T25_A01_S09',
#  'T25_A01_S10',
#  'T25_A01_S11',
#  'T25_A01_S12',
#  'T26_A01_S01',
#  'T26_A01_S02',
#  'T26_A01_S03',
#  'T26_A01_S04',
#  'T26_A01_S05',
#  'T26_A01_S06',
#  'T26_A01_S07',
#  'T26_A01_S08',
#  'T26_A01_S09',
#  'T26_A01_S10',
#  'T26_A01_S11',
#  'T26_A01_S12',
#  'T27_A01_S01',
#  'T27_A01_S02',
#  'T27_A01_S03',
#  'T27_A01_S04',
#  'T27_A01_S05',
#  'T27_A01_S06',
#  'T27_A01_S07',
#  'T27_A01_S08',
#  'T27_A01_S09',
#  'T27_A01_S10',
#  'T27_A01_S11',
#  'T27_A01_S12',
#  'T28_A01_S01',
#  'T28_A01_S02',
#  'T28_A01_S03',
#  'T28_A01_S04',
#  'T28_A01_S05',
#  'T28_A01_S06',
#  'T28_A01_S07',
#  'T28_A01_S08',
#  'T28_A01_S09',
#  'T28_A01_S10',
#  'T28_A01_S11',
#  'T28_A01_S12',
#  'T29_A01_S01',
#  'T29_A01_S02',
#  'T29_A01_S03',
#  'T29_A01_S04',
#  'T29_A01_S05',
#  'T29_A01_S06',
#  'T29_A01_S07',
#  'T29_A01_S08',
#  'T29_A01_S09',
#  'T29_A01_S10',
#  'T29_A01_S11',
#  'T29_A01_S12',
#  'T30_A01_S01',
#  'T30_A01_S02',
#  'T30_A01_S03',
#  'T30_A01_S04',
#  'T30_A01_S05',
#  'T30_A01_S06',
#  'T30_A01_S07',
#  'T30_A01_S08',
#  'T30_A01_S09',
#  'T30_A01_S10',
#  'T30_A01_S11',
#  'T30_A01_S12',
#  'T31_A01_S01',
#  'T31_A01_S02',
#  'T31_A01_S03',
#  'T31_A01_S04',
#  'T31_A01_S05',
#  'T31_A01_S06',
#  'T31_A01_S07',
#  'T31_A01_S08',
#  'T31_A01_S09',
#  'T31_A01_S10',
#  'T31_A01_S11',
#  'T31_A01_S12',
#  'T32_A01_S01',
#  'T32_A01_S02',
#  'T32_A01_S03',
#  'T32_A01_S04',
#  'T32_A01_S05',
#  'T32_A01_S06',
#  'T32_A01_S07',
#  'T32_A01_S08',
#  'T32_A01_S09',
#  'T32_A01_S10',
#  'T32_A01_S11',
#  'T32_A01_S12',
#  'T33_A01_S01',
#  'T33_A01_S02',
#  'T33_A01_S03',
#  'T33_A01_S04',
#  'T33_A01_S05',
#  'T33_A01_S06',
#  'T33_A01_S07',
#  'T33_A01_S08',
#  'T33_A01_S09',
#  'T33_A01_S10',
#  'T33_A01_S11',
#  'T33_A01_S12',
#  'T34_A01_S01',
#  'T34_A01_S02',
#  'T34_A01_S03',
#  'T34_A01_S04',
#  'T34_A01_S05',
#  'T34_A01_S06',
#  'T34_A01_S07',
#  'T34_A01_S08',
#  'T34_A01_S09',
#  'T34_A01_S10',
#  'T34_A01_S11',
#  'T34_A01_S12',
#  'T35_A01_S01',
#  'T35_A01_S02',
#  'T35_A01_S03',
#  'T35_A01_S04',
#  'T35_A01_S05',
#  'T35_A01_S06',
#  'T35_A01_S07',
#  'T35_A01_S08',
#  'T35_A01_S09',
#  'T35_A01_S10',
#  'T35_A01_S11',
#  'T35_A01_S12',
#  'T36_A01_S01',
#  'T36_A01_S02',
#  'T36_A01_S03',
#  'T36_A01_S04',
#  'T36_A01_S05',
#  'T36_A01_S06',
#  'T36_A01_S07',
#  'T36_A01_S08',
#  'T36_A01_S09',
#  'T36_A01_S10',
#  'T36_A01_S11',
#  'T36_A01_S12',
#  'T37_A01_S01',
#  'T37_A01_S02',
#  'T37_A01_S03',
#  'T37_A01_S04',
#  'T37_A01_S05',
#  'T37_A01_S06',
#  'T37_A01_S07',
#  'T37_A01_S08',
#  'T37_A01_S09',
#  'T37_A01_S10',
#  'T37_A01_S11',
#  'T37_A01_S12',
#  'T38_A01_S01',
#  'T38_A01_S02',
#  'T38_A01_S03',
#  'T38_A01_S04',
#  'T38_A01_S05',
#  'T38_A01_S06',
#  'T38_A01_S07',
#  'T38_A01_S08',
#  'T39_A01_S01',
#  'T39_A01_S02',
#  'T39_A01_S03',
#  'T39_A01_S04',
#  'T39_A01_S05',
#  'T39_A01_S06',
#  'T39_A01_S07',
#  'T39_A01_S08',
#  'T39_A01_S09',
#  'T39_A01_S10',
#  'T39_A01_S11',
#  'T39_A01_S12',
#  'T40_A01_S01',
#  'T40_A01_S02',
#  'T40_A01_S03',
#  'T40_A01_S04',
#  'T40_A01_S05',
#  'T40_A01_S06',
#  'T40_A01_S07',
#  'T40_A01_S08',
#  'T40_A01_S09',
#  'T40_A01_S10',
#  'T40_A01_S11',
#  'T40_A01_S12',
#  'T41_A01_S01',
#  'T41_A01_S02',
#  'T41_A01_S03',
#  'T41_A01_S04',
#  'T41_A01_S05',
#  'T41_A01_S06',
#  'T41_A01_S07',
#  'T41_A01_S08',
#  'T41_A01_S09',
#  'T41_A01_S10',
#  'T41_A01_S11',
#  'T41_A01_S12']

# %%
# 가끔 숫자 앞에 0을 채우고 싶을 때가 있음
# 그럴때는 문자열로 변환 후, zfill()을 사용하면 된다.
# 숫자형에서 적용시 오류가 나므로 문자로 변환 후 사용할 것.
# zfill()의 괄호 안에는 출력하고자 하는 문자열의 총 길이를 입력하면 된다.

x = 2
type(x)

print(str(x).zfill(2))
# 02

print(str(x).zfill(3))
# 002
# Out:
# 02
# 002

# %%
Action_Num = [1,4,5,6,7,8,10,14]
print(str(Action_Num[6]).zfill(2))
# Out:
# 10

# %%
import os 
os.makedirs("a/b/c/d")
# a안에 b안에 c안에 d 폴더 생성
# 하지만, a/b/c/d가 모두 이미 존재하는 폴더라면 오류 발생.

# %%
# 폴더생성 기본 코드
import os 
os.mkdir("C:/Users/user/Desktop/Taekwondo/DataSet/GoodFolder1")

# %%
# 현재 위치 알아내는 코드
import os 
current_path = os.getcwd() 
print("현재 위치 : " + current_path)

# 출처: https://blockdmask.tistory.com/554 [개발자 지망생]
# Out:
# 현재 위치 : C:\JupyterTest

# %%
# 12프레임단위로 추출하는 코드
import cv2
for()
vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01')
file_name = 'T38_A01_S01.mp4'
count = 0

while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if(int(vidcap.get(1)) % 20 == 0):             # 여기가 프레임 수정하는 코드
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        cv2.imwrite("../data/Taekwondo/train/frame%d.png" % count, image)
        print('Saved frame%d.jpg' % count)
        count += 1

# %%
for Set in range(2, 10):
        os.mkdir(my_path + file_name + str(Set))
    file_name = 'T38_A01_S01.mp4'
    print('T%d_A%d_S%d.jpg',%Trainer, %Action,%Set)

# %%
# 12프레임단위로 추출하는 코드
import cv2
vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01/T38_A01_S01.mp4')

Trainer= 1
Action = 1
Set = 0

for Action in range(1,9):
    video_path = "C:/Users/user/Desktop/Taekwondo/DataSet/A01"
    
    # 비디오 생성 경로 변경 코드 필요
    
    
# 이미지 추출
while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if(int(vidcap.get(1)) % 12 == 0):             # 여기가 프레임 수정하는 코드
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        cv2.imwrite('video_path + T%d_A%d_S%d.jpg', % Trainer, % Action,% Set, image)
        # 바뀌는 비디오 경로 + 바뀌는 파일명
        print('Saved frame%d.jpg' % count)
        Set += 1    # 여기서 파일명을 바꿔준다.

# %%
# 12프레임단위로 추출하는 코드(성공)
import cv2
vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01/T38_A01_S01.mp4')
# cv2.VideoCapture 공부해서 여러 파일 자동으로 읽어들일 수 있는지 확인

Trainer= 1
Action = 1
Set = 0
# 생성되는 이미지 파일경로, 
# for문으로 폴더내에 모든 영상추출하면 
# 폴더생성 -> path 수정해서 추출
img_path = "C:/Users/user/Desktop/Taekwondo/DataSet/A01/"
    
# 이미지 추출
while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if(int(vidcap.get(1)) % 12 == 0):             # 여기가 프레임 수정하는 코드
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        #cv2.imwrite('img_path + T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        cv2.imwrite('C:/Users/user/Desktop/Taekwondo/DataSet/A01/T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        # 바뀌는 비디오 경로 + 바뀌는 파일명
        print('Saved T%d_A%d_S%d.jpg' %(Trainer, Action, Set))
        Set += 1    # 여기서 파일명을 바꿔준다.
# Out:
# Saved frame number : 12
# Saved T1_A1_S0.jpg
# Saved frame number : 24
# Saved T1_A1_S1.jpg
# Saved frame number : 24
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [2], in <cell line: 15>()
#      18 print('Saved frame number : ' + str(int(vidcap.get(1))))
#      19 #cv2.imwrite('img_path + T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
# ---> 20 cv2.imwrite('C:/Users/user/Desktop/Taekwondo/DataSet/A01/T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
#      21 # 바뀌는 비디오 경로 + 바뀌는 파일명
#      22 print('Saved T%d_A%d_S%d.jpg' %(Trainer, Action, Set))
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
# 12프레임단위로 추출하는 코드(성공+복사본)
import cv2
vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01/T38_A01_S01.mp4')
# cv2.VideoCapture 공부해서 여러 파일 자동으로 읽어들일 수 있는지 확인

Trainer= 1
Action = 1
Set = 0
# 생성되는 이미지 파일경로, 
# for문으로 폴더내에 모든 영상추출하면 
# 폴더생성 -> path 수정해서 추출
img_path = "C:/Users/user/Desktop/Taekwondo/DataSet/A01"
    
# 이미지 추출
while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if(int(vidcap.get(1)) % 12 == 0):             # 여기가 프레임 수정하는 코드
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        # cv2.imwrite('img_path + T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        cv2.imwrite('C:/Users/user/Desktop/Taekwondo/DataSet/A01/T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        # 바뀌는 비디오 경로 + 바뀌는 파일명
        print('Saved T%d_A%d_S%d.jpg' %(Trainer, Action, Set))
        Set += 1    # 여기서 파일명을 바꿔준다.
# Out:
# Saved frame number : 12
# Saved T1_A1_S0.jpg
# Saved frame number : 24
# Saved T1_A1_S1.jpg
# Saved frame number : 24
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [13], in <cell line: 15>()
#      18 print('Saved frame number : ' + str(int(vidcap.get(1))))
#      19 # cv2.imwrite('img_path + T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
# ---> 20 cv2.imwrite('C:/Users/user/Desktop/Taekwondo/DataSet/A01/T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
#      21 # 바뀌는 비디오 경로 + 바뀌는 파일명
#      22 print('Saved T%d_A%d_S%d.jpg' %(Trainer, Action, Set))
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
# 12프레임단위로 추출하는 코드(수정중)
import cv2
vidcap = cv2.VideoCapture('C:/Users/user/Desktop/Taekwondo/test/A01/T38_A01_S01.mp4')
# cv2.VideoCapture 공부해서 여러 파일 자동으로 읽어들일 수 있는지 확인

Trainer= 1
Action = 1
Set = 0
# 생성되는 이미지 파일경로, 
# for문으로 폴더내에 모든 영상추출하면 
# 폴더생성 -> path 수정해서 추출
for Action in range(1,9):
    count=0
    img_path = "C:/Users/user/Desktop/Taekwondo/DataSet/" + "folder_name + str(num).zfill(2)"
    img = "/T%d_A%d_S%d_count"
    count++
    
# 이미지 추출
while(vidcap.isOpened()):
    ret, image = vidcap.read()
    if(int(vidcap.get(1)) % 12 == 0):             # 여기가 프레임 수정하는 코드
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        # cv2.imwrite('img_path + T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        cv2.imwrite('C:/Users/user/Desktop/Taekwondo/DataSet/A01/T%d_A%d_S%d.jpg' %(Trainer, Action, Set), image)
        # 바뀌는 비디오 경로 + 바뀌는 파일명
        print('Saved T%d_A%d_S%d.jpg' %(Trainer, Action, Set))
        Set += 1    # 여기서 파일명을 바꿔준다.
# Out:
#   Input In [4]
#     count++
#            ^
# SyntaxError: invalid syntax
